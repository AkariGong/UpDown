# %%
import os
import glob
import cv2
import pickle
import deeplabcut

import numpy as np
# Out:
# Loading DLC 2.2.1.1...
# c:\Users\Tytell_Admin\.conda\envs\DEEPLABCUT\lib\site-packages\statsmodels\compat\pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex
# c:\Users\Tytell_Admin\.conda\envs\DEEPLABCUT\lib\site-packages\deeplabcut\__init__.py:81: UserWarning:
#         As PyTorch is not installed, unsupervised identity learning will not be available.
#         Please run `pip install torch`, or ignore this warning.
#
#   warnings.warn(

# %% [markdown]
# calibration file: 20220706_checkerboard_cal02
#
# trials: all 20220706 ms02 trials

# %% [markdown]
# # Set up the 3D DeepLabCut project

# %% [markdown]
# Change the base path for each different 3D project

# %%
base_path = r'D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d'

# %%
config_path_3d = os.path.join(base_path, 'config.yaml')

if os.path.exists(config_path_3d):
    print('Found existing 3d project')
else:
    print('Create new 3d project!')
    deeplabcut.create_new_project_3d('UpAndDown','Ming', 2)
# Out:
# Found existing 3d project

# %% [markdown]
# Make sure you edit the 3D config.yaml file. The cameras should be named 'rear' and 'lateral', and the config file paths for the 2D tracking should be updated correctly. Also update the skeleton to match the 2D tracking.

# %% [markdown]
# # Do the calibration

# %% [markdown]
# See https://github.com/DeepLabCut/DeepLabCut/blob/master/docs/Overviewof3D.md for an overview

# %% [markdown]
# Most of the code below is modified from the DLC repository here: https://github.com/DeepLabCut/DeepLabCut/blob/master/deeplabcut/pose_estimation_3d/camera_calibration.py

# %% [markdown]
# Number of internal corners on our checkboard. (e.g., 8x8 squares has 7x7 internal corners)

# %%
cbrow = 9
cbcol = 6

# %%
cam_names = ['rear', 'lateral']

# %%
framedir = os.path.join(base_path, 'calibration_images')
print(framedir)
cornerdir = os.path.join(base_path, 'corners')
print(cornerdir)
# Out:
# D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\calibration_images
# D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\corners

# %%
filenames = []
for cam1 in cam_names:
    fn1 = glob.glob(os.path.join(framedir, cam1 + '*.jpg'))
    fn1.sort()
    filenames.append(fn1)

filenames = np.array(filenames)

print(filenames[:,:3])
# Out:
# [['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-001.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-002.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-003.jpg']
#  ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-001.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-002.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-003.jpg']]

# %%
print(filenames)
# Out:
# [['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-001.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-002.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-003.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-004.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-005.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-006.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-007.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-008.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-009.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-010.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-011.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-012.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-013.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-014.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-015.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-016.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-017.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-018.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-019.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-020.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-021.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-022.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-023.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-024.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-025.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-026.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-027.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-028.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-029.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-030.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-031.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-032.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-033.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-034.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-035.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-036.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-037.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-038.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-039.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-040.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-041.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-042.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-043.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-044.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-045.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-046.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-047.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-048.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-049.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-050.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-051.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-052.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-053.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-054.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-055.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-056.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-057.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-058.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-059.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-060.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-061.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-062.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-063.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-064.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-065.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-066.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-067.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-068.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-069.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-070.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-071.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-072.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-073.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-074.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-075.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-076.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-077.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-078.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-079.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-080.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-081.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-082.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-083.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-084.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-085.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-086.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-087.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-088.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-089.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\rear-090.jpg']
#  ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-001.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-002.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-003.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-004.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-005.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-006.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-007.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-008.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-009.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-010.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-011.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-012.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-013.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-014.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-015.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-016.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-017.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-018.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-019.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-020.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-021.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-022.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-023.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-024.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-025.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-026.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-027.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-028.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-029.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-030.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-031.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-032.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-033.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-034.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-035.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-036.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-037.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-038.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-039.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-040.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-041.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-042.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-043.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-044.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-045.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-046.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-047.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-048.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-049.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-050.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-051.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-052.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-053.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-054.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-055.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-056.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-057.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-058.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-059.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-060.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-061.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-062.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-063.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-064.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-065.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-066.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-067.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-068.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-069.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-070.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-071.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-072.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-073.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-074.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-075.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-076.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-077.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-078.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-079.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-080.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-081.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-082.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-083.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-084.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-085.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-086.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-087.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-088.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-089.jpg'
#   'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\calibration_images\\lateral-090.jpg']]

# %%
def dir_name(path):
    file_list = os.listdir(path)
    file_name_list = []
    for i in range(len(file_list)):
        file_name = path + '/' + file_list[i]
        file_name_list.append(file_name)
    return file_name_list

def files_name(path):
    filesname_list = []
    for i in range(len(path)):
        (filepath, tempfilename) = os.path.split(path[i])
        (filesname, extension) = os.path.splitext(tempfilename)
        filesname_list.append(filesname)
    print(filesname_list)
    return filesname_list

# %%
files_path = dir_name(framedir)

# %%
rotategrid = {}
keys = files_name(files_path)
values = [{'fliplr': True, 'rotate': 0},
          {'fliplr': False, 'rotate': 0}]

for i in keys:
        if i.startswith('lateral'):
                rotategrid[i] = values[0]
                
        else:
                rotategrid[i] = values[1]

print(rotategrid)
# Out:
# ['lateral-001', 'lateral-002', 'lateral-003', 'lateral-004', 'lateral-005', 'lateral-006', 'lateral-007', 'lateral-008', 'lateral-009', 'lateral-010', 'lateral-011', 'lateral-012', 'lateral-013', 'lateral-014', 'lateral-015', 'lateral-016', 'lateral-017', 'lateral-018', 'lateral-019', 'lateral-020', 'lateral-021', 'lateral-022', 'lateral-023', 'lateral-024', 'lateral-025', 'lateral-026', 'lateral-027', 'lateral-028', 'lateral-029', 'lateral-030', 'lateral-031', 'lateral-032', 'lateral-033', 'lateral-034', 'lateral-035', 'lateral-036', 'lateral-037', 'lateral-038', 'lateral-039', 'lateral-040', 'lateral-041', 'lateral-042', 'lateral-043', 'lateral-044', 'lateral-045', 'lateral-046', 'lateral-047', 'lateral-048', 'lateral-049', 'lateral-050', 'lateral-051', 'lateral-052', 'lateral-053', 'lateral-054', 'lateral-055', 'lateral-056', 'lateral-057', 'lateral-058', 'lateral-059', 'lateral-060', 'lateral-061', 'lateral-062', 'lateral-063', 'lateral-064', 'lateral-065', 'lateral-066', 'lateral-067', 'lateral-068', 'lateral-069', 'lateral-070', 'lateral-071', 'lateral-072', 'lateral-073', 'lateral-074', 'lateral-075', 'lateral-076', 'lateral-077', 'lateral-078', 'lateral-079', 'lateral-080', 'lateral-081', 'lateral-082', 'lateral-083', 'lateral-084', 'lateral-085', 'lateral-086', 'lateral-087', 'lateral-088', 'lateral-089', 'lateral-090', 'rear-001', 'rear-002', 'rear-003', 'rear-004', 'rear-005', 'rear-006', 'rear-007', 'rear-008', 'rear-009', 'rear-010', 'rear-011', 'rear-012', 'rear-013', 'rear-014', 'rear-015', 'rear-016', 'rear-017', 'rear-018', 'rear-019', 'rear-020', 'rear-021', 'rear-022', 'rear-023', 'rear-024', 'rear-025', 'rear-026', 'rear-027', 'rear-028', 'rear-029', 'rear-030', 'rear-031', 'rear-032', 'rear-033', 'rear-034', 'rear-035', 'rear-036', 'rear-037', 'rear-038', 'rear-039', 'rear-040', 'rear-041', 'rear-042', 'rear-043', 'rear-044', 'rear-045', 'rear-046', 'rear-047', 'rear-048', 'rear-049', 'rear-050', 'rear-051', 'rear-052', 'rear-053', 'rear-054', 'rear-055', 'rear-056', 'rear-057', 'rear-058', 'rear-059', 'rear-060', 'rear-061', 'rear-062', 'rear-063', 'rear-064', 'rear-065', 'rear-066', 'rear-067', 'rear-068', 'rear-069', 'rear-070', 'rear-071', 'rear-072', 'rear-073', 'rear-074', 'rear-075', 'rear-076', 'rear-077', 'rear-078', 'rear-079', 'rear-080', 'rear-081', 'rear-082', 'rear-083', 'rear-084', 'rear-085', 'rear-086', 'rear-087', 'rear-088', 'rear-089', 'rear-090']
# {'lateral-001': {'fliplr': True, 'rotate': 0}, 'lateral-002': {'fliplr': True, 'rotate': 0}, 'lateral-003': {'fliplr': True, 'rotate': 0}, 'lateral-004': {'fliplr': True, 'rotate': 0}, 'lateral-005': {'fliplr': True, 'rotate': 0}, 'lateral-006': {'fliplr': True, 'rotate': 0}, 'lateral-007': {'fliplr': True, 'rotate': 0}, 'lateral-008': {'fliplr': True, 'rotate': 0}, 'lateral-009': {'fliplr': True, 'rotate': 0}, 'lateral-010': {'fliplr': True, 'rotate': 0}, 'lateral-011': {'fliplr': True, 'rotate': 0}, 'lateral-012': {'fliplr': True, 'rotate': 0}, 'lateral-013': {'fliplr': True, 'rotate': 0}, 'lateral-014': {'fliplr': True, 'rotate': 0}, 'lateral-015': {'fliplr': True, 'rotate': 0}, 'lateral-016': {'fliplr': True, 'rotate': 0}, 'lateral-017': {'fliplr': True, 'rotate': 0}, 'lateral-018': {'fliplr': True, 'rotate': 0}, 'lateral-019': {'fliplr': True, 'rotate': 0}, 'lateral-020': {'fliplr': True, 'rotate': 0}, 'lateral-021': {'fliplr': True, 'rotate': 0}, 'lateral-022': {'fliplr': True, 'rotate': 0}, 'lateral-023': {'fliplr': True, 'rotate': 0}, 'lateral-024': {'fliplr': True, 'rotate': 0}, 'lateral-025': {'fliplr': True, 'rotate': 0}, 'lateral-026': {'fliplr': True, 'rotate': 0}, 'lateral-027': {'fliplr': True, 'rotate': 0}, 'lateral-028': {'fliplr': True, 'rotate': 0}, 'lateral-029': {'fliplr': True, 'rotate': 0}, 'lateral-030': {'fliplr': True, 'rotate': 0}, 'lateral-031': {'fliplr': True, 'rotate': 0}, 'lateral-032': {'fliplr': True, 'rotate': 0}, 'lateral-033': {'fliplr': True, 'rotate': 0}, 'lateral-034': {'fliplr': True, 'rotate': 0}, 'lateral-035': {'fliplr': True, 'rotate': 0}, 'lateral-036': {'fliplr': True, 'rotate': 0}, 'lateral-037': {'fliplr': True, 'rotate': 0}, 'lateral-038': {'fliplr': True, 'rotate': 0}, 'lateral-039': {'fliplr': True, 'rotate': 0}, 'lateral-040': {'fliplr': True, 'rotate': 0}, 'lateral-041': {'fliplr': True, 'rotate': 0}, 'lateral-042': {'fliplr': True, 'rotate': 0}, 'lateral-043': {'fliplr': True, 'rotate': 0}, 'lateral-044': {'fliplr': True, 'rotate': 0}, 'lateral-045': {'fliplr': True, 'rotate': 0}, 'lateral-046': {'fliplr': True, 'rotate': 0}, 'lateral-047': {'fliplr': True, 'rotate': 0}, 'lateral-048': {'fliplr': True, 'rotate': 0}, 'lateral-049': {'fliplr': True, 'rotate': 0}, 'lateral-050': {'fliplr': True, 'rotate': 0}, 'lateral-051': {'fliplr': True, 'rotate': 0}, 'lateral-052': {'fliplr': True, 'rotate': 0}, 'lateral-053': {'fliplr': True, 'rotate': 0}, 'lateral-054': {'fliplr': True, 'rotate': 0}, 'lateral-055': {'fliplr': True, 'rotate': 0}, 'lateral-056': {'fliplr': True, 'rotate': 0}, 'lateral-057': {'fliplr': True, 'rotate': 0}, 'lateral-058': {'fliplr': True, 'rotate': 0}, 'lateral-059': {'fliplr': True, 'rotate': 0}, 'lateral-060': {'fliplr': True, 'rotate': 0}, 'lateral-061': {'fliplr': True, 'rotate': 0}, 'lateral-062': {'fliplr': True, 'rotate': 0}, 'lateral-063': {'fliplr': True, 'rotate': 0}, 'lateral-064': {'fliplr': True, 'rotate': 0}, 'lateral-065': {'fliplr': True, 'rotate': 0}, 'lateral-066': {'fliplr': True, 'rotate': 0}, 'lateral-067': {'fliplr': True, 'rotate': 0}, 'lateral-068': {'fliplr': True, 'rotate': 0}, 'lateral-069': {'fliplr': True, 'rotate': 0}, 'lateral-070': {'fliplr': True, 'rotate': 0}, 'lateral-071': {'fliplr': True, 'rotate': 0}, 'lateral-072': {'fliplr': True, 'rotate': 0}, 'lateral-073': {'fliplr': True, 'rotate': 0}, 'lateral-074': {'fliplr': True, 'rotate': 0}, 'lateral-075': {'fliplr': True, 'rotate': 0}, 'lateral-076': {'fliplr': True, 'rotate': 0}, 'lateral-077': {'fliplr': True, 'rotate': 0}, 'lateral-078': {'fliplr': True, 'rotate': 0}, 'lateral-079': {'fliplr': True, 'rotate': 0}, 'lateral-080': {'fliplr': True, 'rotate': 0}, 'lateral-081': {'fliplr': True, 'rotate': 0}, 'lateral-082': {'fliplr': True, 'rotate': 0}, 'lateral-083': {'fliplr': True, 'rotate': 0}, 'lateral-084': {'fliplr': True, 'rotate': 0}, 'lateral-085': {'fliplr': True, 'rotate': 0}, 'lateral-086': {'fliplr': True, 'rotate': 0}, 'lateral-087': {'fliplr': True, 'rotate': 0 ...

# %%
# Termination criteria
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)

# %%
# Prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((cbrow * cbcol, 3), np.float32)
objp[:, :2] = np.mgrid[0:cbcol, 0:cbrow].T.reshape(-1, 2)

# %%
img_shape = {}
objpoints = {}  # 3d point in real world space
imgpoints = {}  # 2d points in image plane.
dist_pickle = {}
stereo_params = {}
for cam in cam_names:
    objpoints.setdefault(cam, [])
    imgpoints.setdefault(cam, [])
    dist_pickle.setdefault(cam, [])

for cam, camfiles1 in zip(cam_names, filenames):
    for fn1 in camfiles1:
        img = cv2.imread(fn1)  # read in an image
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # convert the color of an image 
 
        pn, fn = os.path.split(fn1)
        fn, ext = os.path.splitext(fn)

        print('{}'.format(fn))
        ret, corners = cv2.findChessboardCorners(gray, (cbcol,cbrow), cv2.CALIB_CB_ADAPTIVE_THRESH + \
            cv2.CALIB_CB_FAST_CHECK + cv2.CALIB_CB_NORMALIZE_IMAGE)

        if ret:
            print('Found checkboard corners!')

            corners = cv2.cornerSubPix(gray, corners, (11, 11), (-1, -1), criteria)

            if fn in rotategrid:
                # corners = corners.reshape((cbcol,cbrow, -1))  # divide into cbcol matrices, each has cbrow rows and 1 col.
                corners = corners.reshape((cbrow,cbcol, -1))

                if 'fliplr' in rotategrid[fn] and \
                    rotategrid[fn]['fliplr']:
                    corners = np.flip(corners, axis=1)
                    # corners = np.fliplr(corners)
                
                if 'rotate' in rotategrid[fn]:
                    r = rotategrid[fn]['rotate']

                    if r == 90:
                        k = 1
                    elif r == -90:
                        k = -1
                    elif r == 180:
                        k = 2
                    else:
                        k = 0

                    corners = np.rot90(corners, k, axes=(0, 1))

                corners = corners.reshape(cbrow*cbcol, 1, -1)
            
            img_shape[cam] = gray.shape[::-1]
            objpoints[cam].append(objp)
            imgpoints[cam].append(corners)            
        else:
            print('Not found')

        img = cv2.drawChessboardCorners(img, (cbcol,cbrow), corners, ret)

        cv2.imwrite(os.path.join(cornerdir, fn + '_corner.jpg'), img)
# Out:
# rear-001
# Found checkboard corners!
# rear-002
# Found checkboard corners!
# rear-003
# Found checkboard corners!
# rear-004
# Found checkboard corners!
# rear-005
# Found checkboard corners!
# rear-006
# Found checkboard corners!
# rear-007
# Found checkboard corners!
# rear-008
# Found checkboard corners!
# rear-009
# Found checkboard corners!
# rear-010
# Found checkboard corners!
# rear-011
# Found checkboard corners!
# rear-012
# Found checkboard corners!
# rear-013
# Found checkboard corners!
# rear-014
# Found checkboard corners!
# rear-015
# Found checkboard corners!
# rear-016
# Found checkboard corners!
# rear-017
# Found checkboard corners!
# rear-018
# Found checkboard corners!
# rear-019
# Found checkboard corners!
# rear-020
# Found checkboard corners!
# rear-021
# Found checkboard corners!
# rear-022
# Found checkboard corners!
# rear-023
# Found checkboard corners!
# rear-024
# Found checkboard corners!
# rear-025
# Found checkboard corners!
# rear-026
# Found checkboard corners!
# rear-027
# Found checkboard corners!
# rear-028
# Found checkboard corners!
# rear-029
# Found checkboard corners!
# rear-030
# Found checkboard corners!
# rear-031
# Found checkboard corners!
# rear-032
# Found checkboard corners!
# rear-033
# Found checkboard corners!
# rear-034
# Found checkboard corners!
# rear-035
# Found checkboard corners!
# rear-036
# Found checkboard corners!
# rear-037
# Found checkboard corners!
# rear-038
# Found checkboard corners!
# rear-039
# Found checkboard corners!
# rear-040
# Found checkboard corners!
# rear-041
# Found checkboard corners!
# rear-042
# Found checkboard corners!
# rear-043
# Found checkboard corners!
# rear-044
# Found checkboard corners!
# rear-045
# Found checkboard corners!
# rear-046
# Found checkboard corners!
# rear-047
# Found checkboard corners!
# rear-048
# Found checkboard corners!
# rear-049
# Found checkboard corners!
# rear-050
# Found checkboard corners!
# rear-051
# Found checkboard corners!
# rear-052
# Found checkboard corners!
# rear-053
# Found checkboard corners!
# rear-054
# Found checkboard corners!
# rear-055
# Found checkboard corners!
# rear-056
# Found checkboard corners!
# rear-057
# Found checkboard corners!
# rear-058
# Found checkboard corners!
# rear-059
# Found checkboard corners!
# rear-060
# Found checkboard corners!
# rear-061
# Found checkboard corners!
# rear-062
# Found checkboard corners!
# rear-063
# Found checkboard corners!
# rear-064
# Found checkboard corners!
# rear-065
# Found checkboard corners!
# rear-066
# Found checkboard corners!
# rear-067
# Found checkboard corners!
# rear-068
# Found checkboard corners!
# rear-069
# Found checkboard corners!
# rear-070
# Found checkboard corners!
# rear-071
# Found checkboard corners!
# rear-072
# Found checkboard corners!
# rear-073
# Found checkboard corners!
# rear-074
# Found checkboard corners!
# rear-075
# Found checkboard corners!
# rear-076
# Found checkboard corners!
# rear-077
# Found checkboard corners!
# rear-078
# Found checkboard corners!
# rear-079
# Found checkboard corners!
# rear-080
# Found checkboard corners!
# rear-081
# Found checkboard corners!
# rear-082
# Found checkboard corners!
# rear-083
# Found checkboard corners!
# rear-084
# Found checkboard corners!
# rear-085
# Found checkboard corners!
# rear-086
# Found checkboard corners!
# rear-087
# Found checkboard corners!
# rear-088
# Found checkboard corners!
# rear-089
# Found checkboard corners!
# rear-090
# Found checkboard corners!
# lateral-001
# Found checkboard corners!
# lateral-002
# Found checkboard corners!
# lateral-003
# Found checkboard corners!
# lateral-004
# Found checkboard corners!
# lateral-005
# Found checkboard corners!
# lateral-006
# Found checkboard corners!
# lateral-007
# Found checkboard corners!
# lateral-008
# Found checkboard corners!
# lateral-009
# Found checkboard corners!
# lateral-010
# Found checkboard corners!
# lateral-011
# Found checkboard corners!
# lateral-012
# Found checkboard corners!
# lateral-013
# Found checkboard corners!
# lateral-014
# Found checkboard corners!
# lateral-015
# Found checkboard corners!
# lateral-016
# Found checkboard corners!
# lateral-017
# Found checkboard corners!
# lateral-018
# Found checkboard corners!
# lateral-019
# Found checkboard corners!
# lateral-020
# Found checkboard corners!
# lateral-021
# Found checkboard corners!
# lateral-022
# Found checkboard corners!
# lateral-023
# Found checkboard corners!
# lateral-024
# Found checkboard corners!
# lateral-025
# Found checkboard corners!
# lateral-026
# Found checkboard corners!
# lateral-027
# Found checkboard corners!
# lateral-028
# Found checkboard corners!
# lateral-029
# Found checkboard corners!
# lateral-030
# Found checkboard corners!
# lateral-031
# Found checkboard corners!
# lateral-032
# Found checkboard corners!
# lateral-033
# Found checkboard corners!
# lateral-034
# Found checkboard corners!
# lateral-035
# Found checkboard corners!
# lateral-036
# Found checkboard corners!
# lateral-037
# Found checkboard corners!
# lateral-038
# Found checkboard corners!
# lateral-039
# Found checkboard corners!
# lateral-040
# Found checkboard corners!
# lateral-041
# Found checkboard corners!
# lateral-042
# Found checkboard corners!
# lateral-043
# Found checkboard corners!
# lateral-044
# Found checkboard corners!
# lateral-045
# Found checkboard corners!
# lateral-046
# Found checkboard corners!
# lateral-047
# Found checkboard corners!
# lateral-048
# Found checkboard corners!
# lateral-049
# Found checkboard corners!
# lateral-050
# Found checkboard corners!
# lateral-051
# Found checkboard corners!
# lateral-052
# Found checkboard corners!
# lateral-053
# Found checkboard corners!
# lateral-054
# Found checkboard corners!
# lateral-055
# Found checkboard corners!
# lateral-056
# Found checkboard corners!
# lateral-057
# Found checkboard corners!
# lateral-058
# Found checkboard corners!
# lateral-059
# Found checkboard corners!
# lateral-060
# Found checkboard corners!
# lateral-061
# Found checkboard corners!
# lateral-062
# Found checkboard corners!
# lateral-063
# Found checkboard corners!
# lateral-064
# Found checkboard corners!
# lateral-065
# Found checkboard corners!
# lateral-066
# Found checkboard corners!
# lateral-067
# Found checkboard corners!
# lateral-068
# Found checkboard corners!
# lateral-069
# Found checkboard corners!
# lateral-070
# Found checkboard corners!
# lateral-071
# Found checkboard corners!
# lateral-072
# Found checkboard corners!
# lateral-073
# Found checkboard corners!
# lateral-074
# Found checkboard corners!
# lateral-075
# Found checkboard corners!
# lateral-076
# Found checkboard corners!
# lateral-077
# Found checkboard corners!
# lateral-078
# Found checkboard corners!
# lateral-079
# Found checkboard corners!
# lateral-080
# Found checkboard corners!
# lateral-081
# Found checkboard corners!
# lateral-082
# Found checkboard corners!
# lateral-083
# Found checkboard corners!
# lateral-084
# Found checkboard corners!
# lateral-085
# Found checkboard corners!
# lateral-086
# Found checkboard corners!
# lateral-087
# Found checkboard corners!
# lateral-088
# Found checkboard corners!
# lateral-089
# Found checkboard corners!
# lateral-090
# Found checkboard corners!

# %%
path_camera_matrix = os.path.join(base_path,'camera_matrix')

# %%
alpha = 0.8

# %%
for cam in cam_names:
    ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(
        objpoints[cam], imgpoints[cam], img_shape[cam], None, None
    )

    # Save the camera calibration result for later use (we won't use rvecs / tvecs)
    dist_pickle[cam] = {
        "mtx": mtx,
        "dist": dist,
        "objpoints": objpoints[cam],
        "imgpoints": imgpoints[cam],
    }
    pickle.dump(
        dist_pickle,
        open(
            os.path.join(path_camera_matrix, cam + "_intrinsic_params.pickle"),
            "wb",
        ),
    )
    print(
        "Saving intrinsic camera calibration matrices for %s as a pickle file in %s"
        % (cam, os.path.join(path_camera_matrix))
    )

    # Compute mean re-projection errors for individual cameras
    mean_error = 0
    for i in range(len(objpoints[cam])):
        imgpoints_proj, _ = cv2.projectPoints(
            objpoints[cam][i], rvecs[i], tvecs[i], mtx, dist
        )
        error = cv2.norm(imgpoints[cam][i], imgpoints_proj, cv2.NORM_L2) / len(
            imgpoints_proj
        )
        mean_error += error
    print(
        "Mean re-projection error for %s images: %.3f pixels "
        % (cam, mean_error / len(objpoints[cam]))
    )
# Out:
# Saving intrinsic camera calibration matrices for rear as a pickle file in D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\camera_matrix
# Mean re-projection error for rear images: 0.108 pixels
# Saving intrinsic camera calibration matrices for lateral as a pickle file in D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\camera_matrix
# Mean re-projection error for lateral images: 0.030 pixels

# %%
# print(img.shape[:2])
h, w = img.shape[:2]
print(h, w)
# Out:
# 1104 2560

# %%
# Compute stereo calibration for each pair of cameras
camera_pair = [[cam_names[0], cam_names[1]]]
for pair in camera_pair:
    print("Computing stereo calibration for " % pair)
    (
        retval,
        cameraMatrix1,
        distCoeffs1,
        cameraMatrix2,
        distCoeffs2,
        R,
        T,
        E,
        F,
    ) = cv2.stereoCalibrate(
        objpoints[pair[0]],
        imgpoints[pair[0]],
        imgpoints[pair[1]],
        dist_pickle[pair[0]]["mtx"],
        dist_pickle[pair[0]]["dist"],
        dist_pickle[pair[1]]["mtx"],
        dist_pickle[pair[1]]["dist"],
        (h, w),
        flags=cv2.CALIB_FIX_INTRINSIC,
    )

    # Stereo Rectification
    rectify_scale = alpha  # Free scaling parameter check this https://docs.opencv.org/2.4/modules/calib3d/doc/camera_calibration_and_3d_reconstruction.html#fisheye-stereorectify
    R1, R2, P1, P2, Q, roi1, roi2 = cv2.stereoRectify(
        cameraMatrix1,
        distCoeffs1,
        cameraMatrix2,
        distCoeffs2,
        (h, w),
        R,
        T,
        alpha=rectify_scale,
    )

    stereo_params[pair[0] + "-" + pair[1]] = {
        "cameraMatrix1": cameraMatrix1,
        "cameraMatrix2": cameraMatrix2,
        "distCoeffs1": distCoeffs1,
        "distCoeffs2": distCoeffs2,
        "R": R,
        "T": T,
        "E": E,
        "F": F,
        "R1": R1,
        "R2": R2,
        "P1": P1,
        "P2": P2,
        "roi1": roi1,
        "roi2": roi2,
        "Q": Q,
        "image_shape": [img_shape[pair[0]], img_shape[pair[1]]],
    }

print(
    "Saving the stereo parameters for every pair of cameras as a pickle file in %s"
    % str(os.path.join(path_camera_matrix))
)

deeplabcut.auxiliaryfunctions.write_pickle(
    os.path.join(path_camera_matrix, "stereo_params.pickle"), stereo_params
)
print(
    "Camera calibration done! Use the function ``check_undistortion`` to check the check the calibration"
)
# Out:
# Computing stereo calibration for
# Saving the stereo parameters for every pair of cameras as a pickle file in D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\camera_matrix
# Camera calibration done! Use the function ``check_undistortion`` to check the check the calibration

# %%
cameraMatrix2
# Out:
# array([[5.43801254e+03, 0.00000000e+00, 1.27194947e+03],
#        [0.00000000e+00, 5.16680132e+03, 5.46280548e+02],
#        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])

# %% [markdown]
# ## Check undistortion

# %% [markdown]
# This doesn't work, but the triangulation does. Just skip to the triangulation section

# %%
deeplabcut.check_undistortion(config_path_3d, cbrow=cbrow, cbcol=cbcol)

# %%
camera_pair = [[cam_names[0], cam_names[1]]]

# %%
path_undistort = os.path.join(base_path, 'undistortion')

# %%
pairname = camera_pair[0][0] + "-" + camera_pair[0][1]
map2_x, map2_y = cv2.initUndistortRectifyMap(
    stereo_params[pairname]["cameraMatrix2"],
    stereo_params[pairname]["distCoeffs2"],
    stereo_params[pairname]["R2"],
    stereo_params[pairname]["P2"],
    (stereo_params[pairname]["image_shape"][1]),
    cv2.CV_16SC2,
)

# %%
map2_x

# %%
for pair in camera_pair:
        map1_x, map1_y = cv2.initUndistortRectifyMap(
            stereo_params[pair[0] + "-" + pair[1]]["cameraMatrix1"],
            stereo_params[pair[0] + "-" + pair[1]]["distCoeffs1"],
            stereo_params[pair[0] + "-" + pair[1]]["R1"],
            stereo_params[pair[0] + "-" + pair[1]]["P1"],
            (stereo_params[pair[0] + "-" + pair[1]]["image_shape"][0]),
            cv2.CV_16SC2,
        )
        map2_x, map2_y = cv2.initUndistortRectifyMap(
            stereo_params[pair[0] + "-" + pair[1]]["cameraMatrix2"],
            stereo_params[pair[0] + "-" + pair[1]]["distCoeffs2"],
            stereo_params[pair[0] + "-" + pair[1]]["R2"],
            stereo_params[pair[0] + "-" + pair[1]]["P2"],
            (stereo_params[pair[0] + "-" + pair[1]]["image_shape"][1]),
            cv2.CV_16SC2,
        )
        cam1_undistort = []
        cam2_undistort = []

        for camnum, (cam, camfiles1, rot1) in enumerate(zip(cam_names, filenames, rotategrid)):
            for fname in camfiles1:
                _, filename = os.path.split(fname)
                img1 = cv2.imread(fname)
                gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
                h, w = img1.shape[:2]
                _, corners1 = cv2.findChessboardCorners(gray1, (cbcol, cbrow),  cv2.CALIB_CB_ADAPTIVE_THRESH + \
            cv2.CALIB_CB_FAST_CHECK + cv2.CALIB_CB_NORMALIZE_IMAGE)
                
                if rot1:
                    corners1 = corners1.reshape((cbrow,cbcol, -1))
                    corners1 = corners1.transpose((1, 0, 2))
                    corners1 = corners1.reshape((cbrow*cbcol, 1, -1))

                corners_origin1 = cv2.cornerSubPix(
                    gray1, corners1, (11, 11), (-1, -1), criteria
                )
                

                # Remapping dataFrame_camera1_undistort
                im_remapped1 = cv2.remap(gray1, map1_x, map1_y, cv2.INTER_LANCZOS4)
                imgpoints_proj_undistort = cv2.undistortPoints(
                    src=corners_origin1,
                    cameraMatrix=stereo_params[pair[0] + "-" + pair[1]][
                        "cameraMatrix{}".format(camnum+1)
                    ],
                    distCoeffs=stereo_params[pair[0] + "-" + pair[1]]["distCoeffs{}".format(camnum+1)],
                    P=stereo_params[pair[0] + "-" + pair[1]]["P{}".format(camnum+1)],
                    R=stereo_params[pair[0] + "-" + pair[1]]["R{}".format(camnum+1)],
                )
                cam1_undistort.append(imgpoints_proj_undistort)
                cv2.imwrite(
                    os.path.join(str(path_undistort), filename + "_undistort.jpg"),
                    im_remapped1,
                )
                imgpoints_proj_undistort = []

# %%
        cam1_undistort = np.array(cam1_undistort)
        cam2_undistort = np.array(cam2_undistort)
        print("All images are undistorted and stored in %s" % str(path_undistort))
        print(
            "Use the function ``triangulate`` to undistort the dataframes and compute the triangulation"
        )

        if plot == True:
            f1, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
            f1.suptitle(
                str("Original Image: Views from " + pair[0] + " and " + pair[1]),
                fontsize=25,
            )

            # Display images in RGB
            ax1.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
            ax2.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

            norm = mcolors.Normalize(vmin=0.0, vmax=cam1_undistort.shape[1])
            plt.savefig(os.path.join(str(path_undistort), "Original_Image.png"))

            # Plot the undistorted corner points
            f2, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
            f2.suptitle(
                "Undistorted corner points on camera-1 and camera-2", fontsize=25
            )
            ax1.imshow(cv2.cvtColor(im_remapped1, cv2.COLOR_BGR2RGB))
            ax2.imshow(cv2.cvtColor(im_remapped2, cv2.COLOR_BGR2RGB))
            for i in range(0, cam1_undistort.shape[1]):
                ax1.scatter(
                    [cam1_undistort[-1][i, 0, 0]],
                    [cam1_undistort[-1][i, 0, 1]],
                    marker=markerType,
                    s=markerSize,
                    color=markerColor,
                    alpha=alphaValue,
                )
                ax2.scatter(
                    [cam2_undistort[-1][i, 0, 0]],
                    [cam2_undistort[-1][i, 0, 1]],
                    marker=markerType,
                    s=markerSize,
                    color=markerColor,
                    alpha=alphaValue,
                )
            plt.savefig(os.path.join(str(path_undistort), "undistorted_points.png"))

            # Triangulate
            triangulate = auxiliaryfunctions_3d.compute_triangulation_calibration_images(
                stereo_params[pair[0] + "-" + pair[1]],
                cam1_undistort,
                cam2_undistort,
                path_undistort,
                cfg_3d,
                plot=True,
            )
            auxiliaryfunctions.write_pickle("triangulate.pickle", triangulate)

# %% [markdown]
# # Triangulate

# %%
deeplabcut.triangulate(config_path_3d, r'D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos',
                    videotype='.mp4', save_as_csv=True)
# Out:
# List of pairs: [['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_lateral.mp4'], ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial02_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial02_lateral.mp4'], ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial03_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial03_lateral.mp4'], ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial04_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial04_lateral.mp4'], ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial05_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial05_lateral.mp4'], ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial06_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial06_lateral.mp4'], ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial07_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial07_lateral.mp4'], ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial08_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial08_lateral.mp4']]
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial01_rear.mp4 using config_file_rear
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial01_rear
# This file is already analyzed!
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial01_lateral.mp4 using config_file_lateral
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial01_lateral
# This file is already analyzed!
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial02_rear.mp4 using config_file_rear
# Using snapshot-500000 for model D:\UpAndDown\UpAndDownRear4-MingGong-2023-02-10\dlc-models\iteration-0\UpAndDownRear4Feb10-trainset95shuffle1
# c:\Users\Tytell_Admin\.conda\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Starting to analyze %  D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial02_rear.mp4
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.
# D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos 20220706_ms02_trial02_rear DLC_resnet50_UpAndDownRear4Feb10shuffle1_500000
# Filtering with median model D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial02_rear.mp4
# Data from 20220706_ms02_trial02_rear were already filtered. Skipping...
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial02_lateral.mp4 using config_file_lateral
# Using snapshot-500000 for model D:\UpAndDown\UpAndDownLateral5-MingGong-2023-02-08\dlc-models\iteration-0\Lateral5Feb8-trainset95shuffle1
# c:\Users\Tytell_Admin\.conda\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Starting to analyze %  D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial02_lateral.mp4
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.
# D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos 20220706_ms02_trial02_lateral DLC_resnet50_Lateral5Feb8shuffle1_500000
# Filtering with median model D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial02_lateral.mp4
# Data from 20220706_ms02_trial02_lateral were already filtered. Skipping...
# Undistorting...
# Computing the triangulation...
# Triangulated data for video ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_lateral.mp4']
# Results are saved under:  D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial03_rear.mp4 using config_file_rear
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial03_rear
# This file is already analyzed!
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial03_lateral.mp4 using config_file_lateral
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial03_lateral
# This file is already analyzed!
# Undistorting...
# Computing the triangulation...
# Triangulated data for video ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_lateral.mp4']
# Results are saved under:  D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial04_rear.mp4 using config_file_rear
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial04_rear
# This file is already analyzed!
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial04_lateral.mp4 using config_file_lateral
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial04_lateral
# This file is already analyzed!
# Undistorting...
# Computing the triangulation...
# Triangulated data for video ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_lateral.mp4']
# Results are saved under:  D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial05_rear.mp4 using config_file_rear
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial05_rear
# This file is already analyzed!
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial05_lateral.mp4 using config_file_lateral
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial05_lateral
# This file is already analyzed!
# Undistorting...
# Computing the triangulation...
# Triangulated data for video ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_lateral.mp4']
# Results are saved under:  D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial06_rear.mp4 using config_file_rear
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial06_rear
# This file is already analyzed!
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial06_lateral.mp4 using config_file_lateral
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial06_lateral
# This file is already analyzed!
# Undistorting...
# Computing the triangulation...
# Triangulated data for video ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_lateral.mp4']
# Results are saved under:  D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial07_rear.mp4 using config_file_rear
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial07_rear
# This file is already analyzed!
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial07_lateral.mp4 using config_file_lateral
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial07_lateral
# This file is already analyzed!
# Undistorting...
# Computing the triangulation...
# Triangulated data for video ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_lateral.mp4']
# Results are saved under:  D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial08_rear.mp4 using config_file_rear
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial08_rear
# This file is already analyzed!
# Analyzing video D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\20220706_ms02_trial08_lateral.mp4 using config_file_lateral
# Already analyzed...Checking the meta data for any change in the camera matrices and/or scorer names 20220706_ms02_trial08_lateral
# This file is already analyzed!
# Undistorting...
# Computing the triangulation...
# Triangulated data for video ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_lateral.mp4']
# Results are saved under:  D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos
# All videos were analyzed...
# Now you can create 3D video(s) using deeplabcut.create_labeled_video_3d

# %%
deeplabcut.create_labeled_video_3d(config_path_3d, [r'D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos'],
                 videotype='.mp4',
                 start=100, end=200)
# Out:
# Analyzing all the videos in the directory
# [['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_DLC_3D.h5', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial01_lateral.mp4'], ['D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial02_DLC_3D.h5', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial02_rear.mp4', 'D:\\UpAndDown\\UpAndDown-Ming-2023-03-06-3d\\videos\\20220706_ms02_trial02_lateral.mp4']]
# Video already created...
# Creating 3D video from 20220706_ms02_trial02_rear.mp4 and 20220706_ms02_trial02_lateral.mp4 using 20220706_ms02_trial02_DLC_3D.h5
# Looking for filtered predictions...
# Found the following filtered data:  D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\*20220706_ms02_trial02_rearDLC_resnet50_UpAndDownRear4Feb10shuffle1_500000*filtered.h5 D:\UpAndDown\UpAndDown-Ming-2023-03-06-3d\videos\*20220706_ms02_trial02_lateralDLC_resnet50_Lateral5Feb8shuffle1_500000*filtered.h5
# 100%|██████████| 100/100 [00:36<00:00,  2.73it/s]
